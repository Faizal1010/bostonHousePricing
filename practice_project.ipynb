# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/boston_house_prices.csv")
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# Checking for Missing Values
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#### Exploratory Data Analysis (EDA)
## Correlation
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.scatter(dataset['INDUS'], dataset['MEDV'], s= 10)  #Analyzing the relationship between INDUS and MEDV

# %%
#Independent and Dependent Features

X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
## Standardize the Dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([-1.10834602,  0.80843998,  0.34313466,  0.81386426, -1.79804295,
#         2.913858  , -0.29893918, -2.94251148,  2.09419303, -1.44706731,
#        -2.05232232,  1.02375187, -3.88579002])

# %%
#Checking the Parameters on which the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
#Prediction with Test data
pred = regression.predict(X_test)

# %%
#Plot a scatter plot for the prediction
plt.scatter(pred, y_test)

# %%
#calculating the residuals (error)

residuals = y_test-pred
residuals
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: MEDV, Length: 152, dtype: float64

# %%
sns.displot(residuals, kind='kde')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mean_squared_error(y_test, pred)
# Out:
# 21.51744423117721

# %%
mean_absolute_error(y_test, pred)
# Out:
# 3.1627098714574053

# %%
# Performance Metrics

from sklearn.metrics import r2_score, ad

r2_score(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-79dc61febad6> in <cell line: 3>()
#       1 # Performance Metrics
#       2
# ----> 3 from sklearn.metrics import r2_score, ad
#       4
#       5 r2_score(y_test, pred)
#
# ImportError: cannot import name 'ad' from 'sklearn.metrics' (/usr/local/lib/python3.10/dist-packages/sklearn/metrics/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
adjusted_r2 = 1-(((1-0.7112260057484932)*(152-1)/(152-12-1)))
adjusted_r2
# Out:
# 0.6862958767483631

# %%
features = np.array([-1.41105674,  2.26662874, -0.68165068,  1.55181427, -0.94540271,
        0.60196466, -1.29947815,  0.14683092, -1.6302741 , -0.92035152,
       -0.30083661,  0.42854113, -1.25185755])
# features = features.reshape(1, -1)

regression.predict(features)
# features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-60b0369b1c0d> in <cell line: 6>()
#       4 # features = features.reshape(1, -1)
#       5
# ----> 6 regression.predict(features)
#       7 # features
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     384             Returns predicted values.
#     385         """
# --> 386         return self._decision_function(X)
#     387
#     388     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     367         check_is_fitted(self)
#     368
# --> 369         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     371
#
# ...

# %%
import pickle

pickle.dump(regression, open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('/content/regmodel.pkl', 'rb'))
pickled_model.predict(features.reshape(1, -1))
# Out:
# array([34.68987828])
